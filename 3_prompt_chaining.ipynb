# %%
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama

from typing import TypedDict

# %%
llm = ChatOllama(model='llama3.2:3b')

# %%
# create state

class BlogState(TypedDict):
    topic: str
    outline: str
    blog: str

# %%
def generate_outine(state:BlogState) -> BlogState:

    # extract the topic
    topic = state['topic']

    # create a prompt
    prompt = f'Generate a detailed outline on the topic {topic}'

    # call the llm

    outline = llm.invoke(prompt).content

    # update the state
    state['outline']= outline

    return state

# %%
def generate_blog(state:BlogState) -> BlogState:

    # extract the topic
    topic = state['topic']
    outline = state['outline']

    # create a prompt
    prompt = f'Generate a blog on the topic {topic} based upon the detailed outline given below {outline}'

    # call the llm

    blog = llm.invoke(prompt).content

    # update the state
    state['blog']= blog

    return state

# %%
graph = StateGraph(BlogState)

# add node
graph.add_node('generate_outine',generate_outine)
graph.add_node('generate_blog',generate_blog)

# add edge
graph.add_edge(START, 'generate_outine')
graph.add_edge('generate_outine', 'generate_blog')
graph.add_edge('generate_blog', END)

# compile the graph

workflow = graph.compile()

# %%
initial_state = {'topic':'Rise & Fall of IPL'}
final_state = workflow.invoke(initial_state)

outline = final_state['outline']

blog = final_state['blog']

print(outline)
print(blog)
# Out:
# Here is a detailed outline on the rise and fall of the Indian Premier League (IPL):
#
# **I. Introduction**
#
# * A. Definition of IPL
# * B. Brief history of IPL
# * C. Purpose of outline: To analyze the rise and fall of IPL
#
# **II. Rise of IPL (2008-2010)**
#
# * A. Founding of IPL
# 	+ 1. Key players involved: Brijesh Patel, Lalit Modi, and other high-profile cricketers
# 	2. Objective of creating a T20 league in India
# * B. Launch of inaugural season (2008)
# 	+ 1. Teams: Mumbai Indians, Deccan Chargers, Chennai Super Kings, and others
# 	+ 2. Initial reception: Positive reviews from fans and critics
# * C. Factors contributing to IPL's success:
# 	+ 1. Unique concept of T20 cricket in India
# 	+ 2. High-profile players participating
# 	+ 3. Innovative marketing and branding strategies
#
# **III. Peak of IPL (2010-2014)**
#
# * A. Consolidation of popularity
# 	+ 1. Growing fan base: Both domestic and international fans
# 	+ 2. Increased revenue from sponsorships, advertising, and broadcasting rights
# * B. Rise of superstars:
# 	+ 1. Virat Kohli (RCB)
# 	+ 2. MS Dhoni (CSK)
# 	+ 3. other notable players like Yuvraj Singh, Suresh Raina, and Harbhajan Singh
# * C. Impact on Indian cricket:
# 	+ 1. Increased participation of Indian cricketers in the league
# 	+ 2. Improved standards of cricket in India
#
# **IV. Decline and Controversies (2014-2016)**
#
# * A. Scandals and controversies:
# 	+ 1. Spot-fixing scandal (2013)
# 	+ 2. Bidding process irregularities
# 	+ 3. Allegations of match-fixing among players and officials
# * B. Financial struggles:
# 	+ 1. Decline in revenue due to reduced viewership and sponsorship deals
# 	+ 2. Rising operational costs: Player salaries, venue rental, etc.
# * C. Consequences for IPL:
# 	+ 1. Sustained losses and financial difficulties
# 	+ 2. Decreased public confidence in the league
#
# **V. Revival Efforts (2016-Present)**
#
# * A. Changes in leadership and governance:
# 	+ 1. Appointment of new chairman: Rajiv Shinde
# 	+ 2. Reorganization of IPL structure and rules
# * B. Innovative strategies to revive interest:
# 	+ 1. New marketing campaigns
# 	+ 2. Improved streaming services and social media engagement
# * C. Progress so far:
# 	+ 1. Increased viewership: Both in India and globally
# 	+ 2. Rising revenue from broadcasting rights, sponsorships, etc.
#
# **VI. Conclusion**
#
# * A. Summary of IPL's rise and fall
# * B. Lessons learned for future growth and improvement
# * C. Final thoughts on the potential revival and future success of IPL
# The Rise and Fall of IPL: A Story of Triumph and Turmoil
#
# Introduction
#
# The Indian Premier League (IPL) has been a behemoth in the world of cricket, captivating millions of fans with its unique blend of high-stakes entertainment and international star power. From its humble beginnings to its current status as one of the most lucrative sports leagues globally, IPL's journey is a fascinating tale of rise and fall, marked by controversy, financial struggles, and ultimately, revival efforts.
#
# The Birth of a League
#
# In 2008, Indian Premier League was born out of a vision to create a Twenty20 (T20) league in India. Key players involved included Brijesh Patel, Lalit Modi, and other high-profile cricketers who saw the potential for a new format that could capture the imagination of fans across the country. The inaugural season kicked off with four teams: Mumbai Indians, Deccan Chargers, Chennai Super Kings, and others.
#
# The Early Years
#
# IPL's early years were marked by widespread acclaim, with fans and critics alike hailing it as a game-changer in Indian cricket. The unique concept of T20 cricket resonated with audiences, who thronged to stadiums to watch their favorite players take on opponents in high-energy matches. Innovative marketing strategies and partnerships with top brands further fueled the league's popularity.
#
# The Golden Era (2010-2014)
#
# As IPL entered its second phase, it solidified its position as a global sports powerhouse. The league saw an explosion of popularity, with fans from around the world tuning in to watch their favorite players compete on the biggest stage. Superstars like Virat Kohli (RCB), MS Dhoni (CSK), and Yuvraj Singh (Kings XI Punjab) became household names, drawing in millions of new fans.
#
# The Peak of Success
#
# IPL's popularity soared during this period, with revenue from sponsorships, advertising, and broadcasting rights skyrocketing. The league also saw an increase in participation from Indian cricketers, elevating the standards of cricket in the country. However, beneath the surface, cracks began to appear.
#
# Decline and Controversies (2014-2016)
#
# As IPL entered its seventh season, controversy started to plague the league. Spot-fixing scandals, bidding process irregularities, and allegations of match-fixing among players and officials sent shockwaves through the cricket world. The financial struggles were also evident, with declining revenue due to reduced viewership and sponsorship deals.
#
# Financial Struggles
#
# The financial woes deepened as operational costs continued to rise, including player salaries, venue rental, and marketing expenses. Sustained losses and financial difficulties took their toll on the league, leading to a decline in public confidence.
#
# Revival Efforts (2016-Present)
#
# In 2016, IPL underwent a significant transformation with the appointment of new chairman Rajiv Shinde. The league reorganized its structure and rules, introducing changes aimed at improving governance and reducing costs. Innovative marketing strategies, improved streaming services, and social media engagement helped to revive interest.
#
# Progress So Far
#
# IPL has seen an increase in viewership both domestically and globally, with revenue from broadcasting rights and sponsorships on the rise. The league's efforts to improve its image have yielded positive results, but there is still work to be done to restore its former glory.
#
# Conclusion
#
# The rise and fall of IPL serves as a cautionary tale for leagues around the world. While it has faced numerous challenges, including controversy and financial struggles, the league has shown remarkable resilience and adaptability. By learning from its mistakes and embracing innovative strategies, IPL can emerge stronger than ever, cementing its position as one of the most successful sports leagues globally.
#
# Lessons Learned
#
# 1. Effective governance is crucial: The introduction of new leadership and rule changes has helped to stabilize the league.
# 2. Innovative marketing is key: Embracing digital platforms and social media engagement has revitalized interest in the league.
# 3. Diversifying revenue streams is vital: IPL's efforts to increase broadcasting rights, sponsorships, and other revenue sources will be crucial to its long-term success.
#
# Final Thoughts
#
# As IPL looks to the future, it faces stiff competition from other sports leagues around the world. However, with a renewed focus on innovation, governance, and fan engagement, the league has the potential to reclaim its former glory. Will IPL succeed in reviving its fortunes? Only time will tell, but one thing is certain – the journey of this iconic league will continue to captivate fans worldwide for years to come.
