# %%
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama
from typing import TypedDict
from dotenv import load_dotenv

# %%
llm = ChatOllama(model="llama3.2:3b")

# %%
# create state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    
    # extract the question from state
    question = state['question']

    # form a prompt
    prompt  = f'Answer the following question {question}'

    # ask the question to the LLM
    answer = llm.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa', END)

# compile graph
workflow = graph.compile()

# %%
initial_state = {'question': 'What is artemis mission ?'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# The Artemis Mission is a NASA program aimed at returning humans to the lunar surface by 2025. The mission is named after the Greek goddess of the hunt, Artemis, who was also the twin sister of Apollo.
#
# The primary goals of the Artemis Mission are:
#
# 1. To establish a sustainable presence on the Moon and to use it as a stepping stone for further human exploration of the solar system.
# 2. To conduct scientific research on the lunar surface and subsurface, with a focus on understanding the Moon's geology, composition, and potential resources.
# 3. To test technologies and strategies that will be used for future deep space missions, such as those to Mars.
#
# The Artemis Mission involves several key components:
#
# 1. Space Launch System (SLS): A heavy-lift rocket that will carry the Orion spacecraft and the lunar lander on its mission.
# 2. Orion Spacecraft: A crew vehicle designed to take astronauts to the Moon and return them safely to Earth.
# 3. Gateway: A lunar-orbiting space station that will serve as a base for missions to the lunar surface.
# 4. Lunar Lander: A spacecraft that will transport astronauts from the Gateway to the lunar surface.
#
# The Artemis Mission is divided into several phases, including:
#
# 1. Artemis I (2022): An uncrewed mission that will test the SLS rocket and Orion spacecraft on a lunar flyby.
# 2. Artemis II (2023): A crewed mission that will send astronauts on an orbital flight around the Moon using the Orion spacecraft.
# 3. Artemis III (2025): The first crewed mission to land humans on the lunar surface.
#
# Overall, the Artemis Mission represents a major step forward for NASA's plans to return humans to the lunar surface and establish a sustainable presence in space.
